# %% [markdown]
# Build a regression model.

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np

fullDataSet = pd.read_csv('joinedData.csv')

fullDataSet['review_count'] = fullDataSet['review_count'].replace(np.nan,0)

reviewCount = fullDataSet['review_count']
freeBikes = fullDataSet['freeBikes']

freeBikes = sm.add_constant(freeBikes)
line_reg = sm.OLS(reviewCount,freeBikes)


fullDataSet
# Out:
#               restaurant_name               address  rating  review_count  \
# 0                 Tim Hortons     2575 Danforth Ave     5.5           0.0
# 1        Sam James Coffee Bar        297 Harbord St     8.4           0.0
# 2            Le Select Bistro   432 Wellington St W     8.9           0.0
# 3              A&W Restaurant           8 Mercer St     8.2           0.0
# 4               Loga's Corner        216C Close Ave     8.6           0.0
# ...                       ...                   ...     ...           ...
# 1104  Pimento Jerk Food Truck                   NaN     4.5           6.0
# 1105              Food Cabbie                   NaN     4.0           5.0
# 1106               Apple Cafe       840 Coxwell Ave     2.5           4.0
# 1107          Mustache Burger                   NaN     2.5           3.0
# 1108           The Mighty Cob  1107 Derry Road East     5.0           1.0
#
#       reslatitude  reslongitude                  bikeStationAddress  \
# ...

# %% [markdown]
# Provide model output and an interpretation of the results.

# %%
model = line_reg .fit()
print_model = model.summary()
print(print_model)

#since the p value is less than 0.05 there is a strong relationship between the review count of a restaruant and the ammount of availiable bikes in the area
#I believe this is because areas with less availiable bikes are generally more busy leading to more traffic for the business in the area boosting their review count
#this could also be interpretted diffrently as well - it could be possible that because an area has less availible bikes - people are more likely to just go to whichever restaruant is closest 
#
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           review_count   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     11.97
# Date:                Wed, 07 Dec 2022   Prob (F-statistic):           0.000561
# Time:                        07:32:39   Log-Likelihood:                -7393.6
# No. Observations:                1109   AIC:                         1.479e+04
# Df Residuals:                    1107   BIC:                         1.480e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        113.6287      9.315     12.199      0.000      95.352     131.905
# ...

# %% [markdown]
# # Stretch

# %% [markdown]
# How can you turn the regression model into a classification model?
